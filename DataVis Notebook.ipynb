# %%
import pandas as pd

# %%
df = pd.read_json("./webapp/state.json")

# %%
cb_word_freq = df.loc['cb', 'wordFrequencyCount']
notcb_word_freq = df.loc['cb', 'wordFrequencyCount']

# %%
cb_word_freq
notcb_word_freq
# Out:
# {'2': 5,
#  '4': 1,
#  '5': 5,
#  '8': 1,
#  '9': 3,
#  '10': 28,
#  '11': 3,
#  '12': 3,
#  '13': 1,
#  '14': 1,
#  '15': 2,
#  '16': 1,
#  '17': 1,
#  '18': 1,
#  '20': 1,
#  '24': 1,
#  '28': 1,
#  '29': 1,
#  '30': 1,
#  '31': 1,
#  '100': 2,
#  '250': 1,
#  '280': 1,
#  '400': 1,
#  '2017': 2,
#  '2018': 1,
#  '2019': 5,
#  '2020': 1,
#  '737200': 1,
#  'WE': 1,
#  'WANT': 1,
#  'TO': 7,
#  'TALK': 1,
#  'ABOUT': 1,
#  'OUR': 1,
#  'MARRIAGE': 1,
#  'z90312etrue': 44,
#  'Nickelback': 2,
#  'Lyrics': 2,
#  'Real': 2,
#  'or': 3,
#  'Fake': 2,
#  ':': 10,
#  '?': 17,
#  'z90312efalse': 141,
#  'I': 11,
#  'Dare': 1,
#  'You': 14,
#  'GOING': 1,
#  'BALD': 1,
#  '!': 29,
#  'Weeks': 2,
#  'with': 7,
#  'iPhone': 5,
#  'X': 5,
#  'Ice': 1,
#  'Cream': 1,
#  'Gadgets': 1,
#  'put': 1,
#  'to': 10,
#  'the': 16,
#  'Test': 2,
#  'Why': 4,
#  'rise': 2,
#  'of': 10,
#  'robots': 2,
#  'won’t': 2,
#  'mean': 2,
#  'end': 2,
#  'work': 2,
#  'Dion': 1,
#  'Lewis': 1,
#  '1notcb3Yd': 1,
# ...
